# %% [markdown]
# # Online Heavy Hitter Detection using Federated Lossy Counting

# %% [markdown]
# ## Step 0: Preparation
#
# Before we begin with the actual code, let's make sure that we have everything we need.

# %% [markdown]
# ### Installing dependencies
#
# First, we install the necessary packages:

# %%
# !pip3 install -U 'flwr[simulation]'

# %% [markdown]
# Now that we have all dependencies installed, we can import everything we need for this tutorial:

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
# import torch
import flwr as fl

# DEVICE = torch.device("cpu")  # Try "cuda" to train on GPU
# print(
#     f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}"
# )

# %% [markdown]
# ### Data loading
#
# Let's now load the CIFAR-10 training and test set, partition them into ten smaller datasets (each split into training and validation set), and wrap everything in their own `DataLoader`.

# %%
import os
from pathlib import Path

NUM_CLIENTS = 2
nnodes = str(NUM_CLIENTS) + "nodes"
main_src = "/home/paula/ecml2024/"
data_set_paritioned_src = "data_june_1000/"
delimiter = ','
top_n = 30


def load_datasets(num_clients: int, cwd:str):
    # Get a list of all files in the directory
    files = os.listdir(cwd)
    # Filter the files to keep only the CSV files
    csv_files = [os.path.join(cwd,file) for file in files if file.endswith('.csv')]
    return csv_files

# Os clientes apontam para diretórios
def load_subfolders(folder):
    subfolders = []
    print(folder)
    for root, dirs, files in os.walk(folder):
        dirs[:] = [d for d in dirs if d != '.ipynb_checkpoints']
        for dir in dirs:
            subfolders.append(os.path.join(root, dir))
    return subfolders


def count_files_by_folder(directory: str):
    diretorio = Path(directory)
    files = [item for item in diretorio.iterdir() if item.is_file()]
    return len(files)

cwd = "/home/paula/ecml2024/data_june_1000/" + str(nnodes)
onlyfolders = load_subfolders(main_src + data_set_paritioned_src + nnodes)

print(onlyfolders)

num_files = 0
for folder in onlyfolders:
    num_files = count_files_by_folder(folder)
# Out:
# /home/paula/ecml2024/data_june_1000/2nodes
# ['/home/paula/ecml2024/data_june_1000/2nodes/node_0', '/home/paula/ecml2024/data_june_1000/2nodes/node_1']

# %% [markdown]
# ## Client
#
# So far, we've implemented our client by subclassing `flwr.client.NumPyClient`. The three methods we implemented are `get_parameters`, `fit`, and `evaluate`. Finally, we wrap the creation of instances of this class in a function called `client_fn`:

# %%
import pandas as pd
import csv
from datetime import datetime
from river import sketch
from river import stream
import pickle

class FlowerNumPyClient(fl.client.NumPyClient):

    def __init__(self, cid: str, only_folder: str, col_name: str):
        self.cid = cid
        self.onlyfolder = only_folder
        self.colname = col_name
        self.previous_sketch_path = "heavy_hitters_sketch_" + str(self.cid)+".pkl"

    def load_previous_sketch(self):
        """Carrega o heavy_hitters_sketch se o arquivo existir e round > 1."""
        if os.path.exists(self.previous_sketch_path):
            with open(self.previous_sketch_path, 'rb') as f:
                heavy_hitters_sketch = pickle.load(f)
        else:
            heavy_hitters_sketch = None
        return heavy_hitters_sketch
        
    def save_sketch(self, heavy_hitters_sketch):
        """Salva o heavy_hitters_sketch no arquivo."""
        # Garantir que o diretório para o arquivo exista
        directory = os.path.dirname(self.previous_sketch_path)
        if directory:  # Evita erro se o diretório não for especificado
            os.makedirs(directory, exist_ok=True)
        # Salvar o objeto sketch no arquivo
        with open(self.previous_sketch_path, 'wb') as f:
            pickle.dump(heavy_hitters_sketch, f)

    def save_previous_data(self):
        with open('previous_data.pkl', 'wb') as f:
            pickle.dump(self.previous_round_data, f)

    
    def get_next_batch(self, config):
        data = []
        labels = []
        new_file = self.onlyfolder + "/" + "output_" + str(config["current_round"]) + ".csv"
        return new_file

    
    def train(self, config):
        heavy_hitters_sketch = sketch.HeavyHitters(fading_factor=config["fading_factor"], epsilon=config["epsilon"], support=config["support"]) # janelas de tamanho 5000
        #print(config["current_round"])
        
        if (int(config["current_round"]) > 1):
            #if os.path.exists(self.previous_sketch_path):
            with open(self.previous_sketch_path, 'rb') as f:
                heavy_hitters_sketch = pickle.load(f)
        
        cols = ['ANumber','BNumber','DateTime','Action','Result','CountryCode']
        df_bucket_a = pd.DataFrame(columns=['ANumber', 'Count', 'DateTime'])
        new_batch = self.get_next_batch(config)
        X_y = stream.iter_csv(new_batch, delimiter=delimiter, fieldnames=cols)
        for x, y in X_y:
            res = x.__len__()
            if res > 0:
                heavy_hitters_sketch = heavy_hitters_sketch.update(x[self.colname])
                most_common_iter_a = heavy_hitters_sketch.most_common(top_n)
                
                if heavy_hitters_sketch._n % heavy_hitters_sketch._bucket_width == 0:
                    data_obj = datetime.strptime(x['DateTime'], '%Y%m%d%H%M%S')
                    most_common_iter_a = heavy_hitters_sketch.most_common(top_n)
                    bucket_data = x['DateTime']
                    df_new_row = pd.DataFrame(most_common_iter_a, columns=['ANumber', 'Count'])
                    df_new_row['DateTime'] = bucket_data
                    df_new_row = df_new_row.dropna()
                    df_bucket_a = pd.concat([df_bucket_a, df_new_row], axis = 0)
                  
        path_results = main_src + "results_federated/" + data_set_paritioned_src + nnodes + "/node_" + str(self.cid)
        if not os.path.exists(path_results):
             os.makedirs(path_results)
        #print("****** Client *******")
        #print(df_bucket_a)
        df_bucket_a.to_csv(path_results + '/' + "df_bucket_anumber_" + str(config["current_round"]) + ".csv", index=False)

        ## Nova parte para correção do cliente reter a informação e fazer um cumulativo
        # Salvar o sketch atualizado
        self.save_sketch(heavy_hitters_sketch)
        
        return heavy_hitters_sketch, df_bucket_a


    def read_csv_streaming(self, file_path):
        with open(file_path, 'r') as csv_file:
            csv_reader = csv.reader(csv_file)
            for row in csv_reader:
                yield row

    def fit(self, parameters, config):
        hh, df_bucket_hh = self.train(config)

        tuple_bucket_hh = list(df_bucket_hh.values)
        
        # Convertendo a lista de tuplas
        tuple_list = [(x[0], x[1], x[2]) for x in tuple_bucket_hh]

        return tuple_list, 0, {}

    # def evaluate(self, parameters, config):
    #     print(f"[Client {self.cid}] evaluate, config: {config}")
    #     set_parameters(self.net, parameters)
    #     loss, accuracy = test(self.net, self.valloader)
    #     return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

def numpyclient_fn(cid) -> FlowerNumPyClient:
    onlyfolder = onlyfolders[int(cid)]
    col_name = "ANumber"
    return FlowerNumPyClient(cid, onlyfolder, col_name).to_client()

# %% [markdown]
# ### Server-side

# %%
from typing import Callable, Dict, List, Optional, Tuple, Union

import numpy as np

import flwr as fl
from flwr.common import (
    EvaluateIns,
    EvaluateRes,
    FitIns,
    FitRes,
    Parameters,
    Scalar,
    ndarrays_to_parameters,
    parameters_to_ndarrays
)
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy import Strategy

class FedAnalytics(fl.server.strategy.FedAvg):
    def __init__(
            self, min_fit_clients,min_evaluate_clients, min_available_clients, on_fit_config_fn
    ) -> None:
        super().__init__()
        self.min_fit_clients = min_fit_clients
        self.min_evaluate_clients = min_evaluate_clients
        self.min_available_clients = min_available_clients
        self.on_fit_config_fn = on_fit_config_fn

    def __repr__(self) -> str:
        return "FedAnalytics"

    def initialize_parameters(
            self, client_manager: Optional[ClientManager] = None
    ) -> Optional[Parameters]:
        return None

    # Função personalizada para selecionar a data mais recente
    def most_actual_datetime(series):
        return series.loc[series.idxmax()]

    # Aggregation Strategy - aggregate training results
    def aggregate_fit(
            self,
            server_round: int,
            results: List[Tuple[ClientProxy, FitRes]],
            failures: List[Union[Tuple[ClientProxy, FitRes], BaseException]],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        # Get results from fit

        # Convert results
        values_aggregated = [
            (parameters_to_ndarrays(fit_res.parameters)) for _, fit_res in results if len(fit_res.parameters.tensors) > 0
        ]

        lista_filtrada = []
        for lista_de_arrays in values_aggregated:
            nova_lista = [arr for arr in lista_de_arrays if len(arr) > 0]
            lista_filtrada.append(nova_lista)

        lista_filtrada = [arr for arr in lista_filtrada if len(arr) > 0]

        values_hh_numpy = np.empty((0, 3))
        if (len(lista_filtrada) > 0):
            values_hh_numpy = np.concatenate(lista_filtrada)
    
        # # # Criar DataFrame
        if len(values_hh_numpy) > 0:
            df_hh = pd.DataFrame(values_hh_numpy, columns=['Code', 'Value', 'DateTime'])
    
            # # # Converter a coluna 'Valor' para tipo numérico
            df_hh['Value'] = pd.to_numeric(df_hh['Value'])
            df_hh['DateTime'] = pd.to_datetime(df_hh['DateTime'])

            # # Agrupar e agregar os dados
            df_agrupado = df_hh.groupby('Code').agg({'Value': 'sum', 'DateTime': 'max'}).reset_index()
            df_sorted = df_agrupado.sort_values(by='Value', ascending=False)
            
            # Cortando as n primeiras linhas
            #df_cortado = df_sorted.iloc[:top_n]
            df_cortado = df_sorted.iloc[:5].copy()

            df_cortado['Window'] = server_round
    
            path_results = main_src + "results_federated/" + data_set_paritioned_src + nnodes + "/server/"
    
            if not os.path.exists(path_results):
                os.makedirs(path_results)
    
            df_cortado.to_csv(path_results + "df_bucket_anumber_" + str(server_round) + ".csv", index=False)
            
        #print(df_cortado)
        
        return ndarrays_to_parameters([]), {}

    def evaluate(self, server_round: int, parameters: Parameters
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:     
        return 0, {}

    def configure_evaluate(
            self, server_round: int, parameters: Parameters, client_manager: ClientManager
    ) -> List[Tuple[ClientProxy, EvaluateIns]]:
        pass

    def aggregate_evaluate(
            self,
            server_round: int,
            results: List[Tuple[ClientProxy, EvaluateRes]],
            failures: List[Union[Tuple[ClientProxy, EvaluateRes], BaseException]],
    ) -> Tuple[Optional[float], Dict[str, Scalar]]:
        pass

# %% [markdown]
# We've seen this before, there's nothing new so far. The only *tiny* difference compared to the previous notebook is naming, we've changed `FlowerClient` to `FlowerNumPyClient` and `client_fn` to `numpyclient_fn`. Let's run it to see the output we get:

# %%
# a quantidade de subfolders dentro de um folder define a quantidade de clientes

# a subfolder com a maior quantidade de minibatches define o nrounds

import time
import resource

nrounds = num_files
#nrounds = 100
n_clients = NUM_CLIENTS

def fit_config(server_round):
    """Return training configuration dict for each round."""
    config = {
        "fading_factor": 1,
        "epsilon": 0.001,
        "support": 0.0005, # 2 nodes
        #"support": 0.00025, # 4 nodes
        #"support": 0.000125, # 8 nodes
        "current_round": server_round
    }
    return config

strategy = FedAnalytics(
    min_fit_clients=1,
    min_evaluate_clients=1,
    min_available_clients=1,
    on_fit_config_fn=fit_config
    #initial_parameters=fl.common.ndarrays_to_parameters(params)
)

# Specify client resources if you need GPU (defaults to 1 CPU and 0 GPU)
client_resources = {"num_cpus": 4}

start_time = time.time()
before_resources = resource.getrusage(resource.RUSAGE_SELF)

fl.simulation.start_simulation(
    strategy=strategy,
    client_fn=numpyclient_fn,
    num_clients=n_clients,
    config=fl.server.ServerConfig(num_rounds=nrounds, round_timeout=None),
    client_resources=client_resources
)

end_time = time.time() # Tempo de término da execução
elapsed_time = end_time - start_time # Tempo decorrido
# Obtendo informações sobre os recursos após a execução
after_resources = resource.getrusage(resource.RUSAGE_SELF)
# Calculando a diferença entre os recursos antes e depois da execução
diff_resources = {
    "user_time": after_resources.ru_utime - before_resources.ru_utime,
    "system_time": after_resources.ru_stime - before_resources.ru_stime,
    "max_memory": after_resources.ru_maxrss - before_resources.ru_maxrss
}

# Criando um DataFrame com os dados
data = {
    "tempo_execucao": [elapsed_time],
    "user_time": [diff_resources["user_time"]],
    "system_time": [diff_resources["system_time"]],
    "max_memory": [diff_resources["max_memory"]]
}

df = pd.DataFrame(data)

path_results_resources = main_src + "results_federated/" + data_set_paritioned_src + str(NUM_CLIENTS) + "nodes/"

# Salvando o DataFrame em um arquivo CSV
df.to_csv(path_results_resources + "dados_execucao_updated.csv", index=False)
# Out:
# INFO flwr 2024-08-21 11:13:09,652 | app.py:178 | Starting Flower simulation, config: ServerConfig(num_rounds=16453, round_timeout=None)
# 2024-08-21 11:13:12,497	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2024-08-21 11:13:16,273 | app.py:213 | Flower VCE: Ray initialized with resources: {'node:10.40.40.70': 1.0, 'node:__internal_head__': 1.0, 'CPU': 32.0, 'object_store_memory': 73446545817.0, 'memory': 161375273575.0}
# INFO flwr 2024-08-21 11:13:16,275 | app.py:219 | Optimize your simulation with Flower VCE: https://flower.dev/docs/framework/how-to-run-simulations.html
# INFO flwr 2024-08-21 11:13:16,276 | app.py:242 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 4}
# INFO flwr 2024-08-21 11:13:16,308 | app.py:288 | Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO flwr 2024-08-21 11:13:16,310 | server.py:89 | Initializing global parameters
# INFO flwr 2024-08-21 11:13:16,312 | server.py:276 | Requesting initial parameters from one random client
# INFO flwr 2024-08-21 11:13:18,430 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2024-08-21 11:13:18,432 | server.py:91 | Evaluating initial parameters
# INFO flwr 2024-08-21 11:13:18,433 | server.py:94 | initial parameters (loss, other metrics): 0, {}
# INFO flwr 2024-08-21 11:13:18,435 | server.py:104 | FL starting
# DEBUG flwr 2024-08-21 11:13:18,437 | server.py:222 | fit_round 1: strategy sampled 2 clients (out of 2)
# (DefaultActor pid=2479244) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# DEBUG flwr 2024-08-21 11:13:19,174 | server.py:236 | fit_round 1 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:19,211 | server.py:125 | fit progress: (1, 0, {}, 0.7741222456097603)
# INFO flwr 2024-08-21 11:13:19,212 | server.py:171 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:19,214 | server.py:222 | fit_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:19,473 | server.py:236 | fit_round 2 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:19,499 | server.py:125 | fit progress: (2, 0, {}, 1.0630177520215511)
# INFO flwr 2024-08-21 11:13:19,501 | server.py:171 | evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:19,502 | server.py:222 | fit_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:19,779 | server.py:236 | fit_round 3 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:19,803 | server.py:125 | fit progress: (3, 0, {}, 1.3661230877041817)
# INFO flwr 2024-08-21 11:13:19,804 | server.py:171 | evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:19,805 | server.py:222 | fit_round 4: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:20,073 | server.py:236 | fit_round 4 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:20,099 | server.py:125 | fit progress: (4, 0, {}, 1.6622696481645107)
# INFO flwr 2024-08-21 11:13:20,101 | server.py:171 | evaluate_round 4: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:20,102 | server.py:222 | fit_round 5: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:20,384 | server.py:236 | fit_round 5 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:20,411 | server.py:125 | fit progress: (5, 0, {}, 1.974353589117527)
# INFO flwr 2024-08-21 11:13:20,412 | server.py:171 | evaluate_round 5: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:20,414 | server.py:222 | fit_round 6: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:20,702 | server.py:236 | fit_round 6 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:20,730 | server.py:125 | fit progress: (6, 0, {}, 2.2939245477318764)
# INFO flwr 2024-08-21 11:13:20,732 | server.py:171 | evaluate_round 6: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:20,734 | server.py:222 | fit_round 7: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:21,039 | server.py:236 | fit_round 7 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:21,068 | server.py:125 | fit progress: (7, 0, {}, 2.6320563219487667)
# INFO flwr 2024-08-21 11:13:21,070 | server.py:171 | evaluate_round 7: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:21,072 | server.py:222 | fit_round 8: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:21,364 | server.py:236 | fit_round 8 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:21,384 | server.py:125 | fit progress: (8, 0, {}, 2.9480626098811626)
# INFO flwr 2024-08-21 11:13:21,386 | server.py:171 | evaluate_round 8: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:21,387 | server.py:222 | fit_round 9: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:21,672 | server.py:236 | fit_round 9 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:21,700 | server.py:125 | fit progress: (9, 0, {}, 3.263656098395586)
# INFO flwr 2024-08-21 11:13:21,702 | server.py:171 | evaluate_round 9: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:21,703 | server.py:222 | fit_round 10: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:21,993 | server.py:236 | fit_round 10 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:22,022 | server.py:125 | fit progress: (10, 0, {}, 3.585779123008251)
# INFO flwr 2024-08-21 11:13:22,024 | server.py:171 | evaluate_round 10: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:22,025 | server.py:222 | fit_round 11: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:22,331 | server.py:236 | fit_round 11 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:22,358 | server.py:125 | fit progress: (11, 0, {}, 3.921379253268242)
# INFO flwr 2024-08-21 11:13:22,359 | server.py:171 | evaluate_round 11: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:22,361 | server.py:222 | fit_round 12: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:22,647 | server.py:236 | fit_round 12 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:22,675 | server.py:125 | fit progress: (12, 0, {}, 4.238216392695904)
# INFO flwr 2024-08-21 11:13:22,676 | server.py:171 | evaluate_round 12: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:22,677 | server.py:222 | fit_round 13: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:22,977 | server.py:236 | fit_round 13 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:23,006 | server.py:125 | fit progress: (13, 0, {}, 4.569672834128141)
# INFO flwr 2024-08-21 11:13:23,008 | server.py:171 | evaluate_round 13: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:23,009 | server.py:222 | fit_round 14: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:23,315 | server.py:236 | fit_round 14 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:23,341 | server.py:125 | fit progress: (14, 0, {}, 4.904924761503935)
# INFO flwr 2024-08-21 11:13:23,343 | server.py:171 | evaluate_round 14: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:23,344 | server.py:222 | fit_round 15: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:23,666 | server.py:236 | fit_round 15 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:23,691 | server.py:125 | fit progress: (15, 0, {}, 5.2549850679934025)
# INFO flwr 2024-08-21 11:13:23,693 | server.py:171 | evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:23,694 | server.py:222 | fit_round 16: strategy sampled 2 clients (out of 2)
# (DefaultActor pid=2479244) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation. [repeated 30x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# DEBUG flwr 2024-08-21 11:13:24,003 | server.py:236 | fit_round 16 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:24,021 | server.py:125 | fit progress: (16, 0, {}, 5.5850105583667755)
# INFO flwr 2024-08-21 11:13:24,023 | server.py:171 | evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:24,024 | server.py:222 | fit_round 17: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:24,328 | server.py:236 | fit_round 17 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:24,354 | server.py:125 | fit progress: (17, 0, {}, 5.917533632367849)
# INFO flwr 2024-08-21 11:13:24,355 | server.py:171 | evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:24,357 | server.py:222 | fit_round 18: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:24,707 | server.py:236 | fit_round 18 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:24,732 | server.py:125 | fit progress: (18, 0, {}, 6.295879919081926)
# INFO flwr 2024-08-21 11:13:24,734 | server.py:171 | evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:24,735 | server.py:222 | fit_round 19: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:25,065 | server.py:236 | fit_round 19 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:25,090 | server.py:125 | fit progress: (19, 0, {}, 6.65323668718338)
# INFO flwr 2024-08-21 11:13:25,091 | server.py:171 | evaluate_round 19: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:25,092 | server.py:222 | fit_round 20: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:25,412 | server.py:236 | fit_round 20 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:25,439 | server.py:125 | fit progress: (20, 0, {}, 7.002196777611971)
# INFO flwr 2024-08-21 11:13:25,440 | server.py:171 | evaluate_round 20: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:25,441 | server.py:222 | fit_round 21: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:25,766 | server.py:236 | fit_round 21 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:25,795 | server.py:125 | fit progress: (21, 0, {}, 7.358344204723835)
# INFO flwr 2024-08-21 11:13:25,796 | server.py:171 | evaluate_round 21: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:25,797 | server.py:222 | fit_round 22: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:26,133 | server.py:236 | fit_round 22 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:26,161 | server.py:125 | fit progress: (22, 0, {}, 7.724338807165623)
# INFO flwr 2024-08-21 11:13:26,162 | server.py:171 | evaluate_round 22: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:26,163 | server.py:222 | fit_round 23: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:26,517 | server.py:236 | fit_round 23 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:26,545 | server.py:125 | fit progress: (23, 0, {}, 8.108495481312275)
# INFO flwr 2024-08-21 11:13:26,546 | server.py:171 | evaluate_round 23: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:26,549 | server.py:222 | fit_round 24: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:26,887 | server.py:236 | fit_round 24 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:26,914 | server.py:125 | fit progress: (24, 0, {}, 8.477602191269398)
# INFO flwr 2024-08-21 11:13:26,916 | server.py:171 | evaluate_round 24: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:26,917 | server.py:222 | fit_round 25: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:27,247 | server.py:236 | fit_round 25 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:27,275 | server.py:125 | fit progress: (25, 0, {}, 8.838195107877254)
# INFO flwr 2024-08-21 11:13:27,276 | server.py:171 | evaluate_round 25: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:27,278 | server.py:222 | fit_round 26: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:27,606 | server.py:236 | fit_round 26 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:27,633 | server.py:125 | fit progress: (26, 0, {}, 9.196149833500385)
# INFO flwr 2024-08-21 11:13:27,634 | server.py:171 | evaluate_round 26: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:27,636 | server.py:222 | fit_round 27: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:27,958 | server.py:236 | fit_round 27 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:27,986 | server.py:125 | fit progress: (27, 0, {}, 9.549322348088026)
# INFO flwr 2024-08-21 11:13:27,987 | server.py:171 | evaluate_round 27: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:27,989 | server.py:222 | fit_round 28: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:28,296 | server.py:236 | fit_round 28 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:28,321 | server.py:125 | fit progress: (28, 0, {}, 9.884811092168093)
# INFO flwr 2024-08-21 11:13:28,323 | server.py:171 | evaluate_round 28: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:28,324 | server.py:222 | fit_round 29: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:28,643 | server.py:236 | fit_round 29 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:28,670 | server.py:125 | fit progress: (29, 0, {}, 10.233373120427132)
# INFO flwr 2024-08-21 11:13:28,672 | server.py:171 | evaluate_round 29: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:28,673 | server.py:222 | fit_round 30: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:28,979 | server.py:236 | fit_round 30 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:29,003 | server.py:125 | fit progress: (30, 0, {}, 10.567049633711576)
# INFO flwr 2024-08-21 11:13:29,005 | server.py:171 | evaluate_round 30: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:29,006 | server.py:222 | fit_round 31: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:29,317 | server.py:236 | fit_round 31 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:29,343 | server.py:125 | fit progress: (31, 0, {}, 10.906159602105618)
# INFO flwr 2024-08-21 11:13:29,344 | server.py:171 | evaluate_round 31: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:29,345 | server.py:222 | fit_round 32: strategy sampled 2 clients (out of 2)
# (DefaultActor pid=2479244) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation. [repeated 30x across cluster]
# DEBUG flwr 2024-08-21 11:13:29,655 | server.py:236 | fit_round 32 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:29,682 | server.py:125 | fit progress: (32, 0, {}, 11.245139304548502)
# INFO flwr 2024-08-21 11:13:29,683 | server.py:171 | evaluate_round 32: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:29,685 | server.py:222 | fit_round 33: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:29,985 | server.py:236 | fit_round 33 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:30,011 | server.py:125 | fit progress: (33, 0, {}, 11.574390776455402)
# INFO flwr 2024-08-21 11:13:30,012 | server.py:171 | evaluate_round 33: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:30,014 | server.py:222 | fit_round 34: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:30,318 | server.py:236 | fit_round 34 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:30,345 | server.py:125 | fit progress: (34, 0, {}, 11.908498972654343)
# INFO flwr 2024-08-21 11:13:30,347 | server.py:171 | evaluate_round 34: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:30,348 | server.py:222 | fit_round 35: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:30,649 | server.py:236 | fit_round 35 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:30,677 | server.py:125 | fit progress: (35, 0, {}, 12.24027319997549)
# INFO flwr 2024-08-21 11:13:30,678 | server.py:171 | evaluate_round 35: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:30,680 | server.py:222 | fit_round 36: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:30,969 | server.py:236 | fit_round 36 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:30,996 | server.py:125 | fit progress: (36, 0, {}, 12.559341005980968)
# INFO flwr 2024-08-21 11:13:30,998 | server.py:171 | evaluate_round 36: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:30,999 | server.py:222 | fit_round 37: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:31,301 | server.py:236 | fit_round 37 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:31,325 | server.py:125 | fit progress: (37, 0, {}, 12.888991199433804)
# INFO flwr 2024-08-21 11:13:31,327 | server.py:171 | evaluate_round 37: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:31,328 | server.py:222 | fit_round 38: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:31,629 | server.py:236 | fit_round 38 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:31,655 | server.py:125 | fit progress: (38, 0, {}, 13.218706954270601)
# INFO flwr 2024-08-21 11:13:31,657 | server.py:171 | evaluate_round 38: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:31,659 | server.py:222 | fit_round 39: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:31,955 | server.py:236 | fit_round 39 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:31,981 | server.py:125 | fit progress: (39, 0, {}, 13.54508277028799)
# INFO flwr 2024-08-21 11:13:31,983 | server.py:171 | evaluate_round 39: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:31,985 | server.py:222 | fit_round 40: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:32,279 | server.py:236 | fit_round 40 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:32,305 | server.py:125 | fit progress: (40, 0, {}, 13.8684516325593)
# INFO flwr 2024-08-21 11:13:32,306 | server.py:171 | evaluate_round 40: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:32,308 | server.py:222 | fit_round 41: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:32,596 | server.py:236 | fit_round 41 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:32,622 | server.py:125 | fit progress: (41, 0, {}, 14.186060886830091)
# INFO flwr 2024-08-21 11:13:32,624 | server.py:171 | evaluate_round 41: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:32,626 | server.py:222 | fit_round 42: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:32,926 | server.py:236 | fit_round 42 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:32,952 | server.py:125 | fit progress: (42, 0, {}, 14.515822153538465)
# INFO flwr 2024-08-21 11:13:32,954 | server.py:171 | evaluate_round 42: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:32,955 | server.py:222 | fit_round 43: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:33,245 | server.py:236 | fit_round 43 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:33,271 | server.py:125 | fit progress: (43, 0, {}, 14.834601655602455)
# INFO flwr 2024-08-21 11:13:33,272 | server.py:171 | evaluate_round 43: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:33,274 | server.py:222 | fit_round 44: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:33,558 | server.py:236 | fit_round 44 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:33,584 | server.py:125 | fit progress: (44, 0, {}, 15.14718409627676)
# INFO flwr 2024-08-21 11:13:33,585 | server.py:171 | evaluate_round 44: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:33,586 | server.py:222 | fit_round 45: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:33,869 | server.py:236 | fit_round 45 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:33,898 | server.py:125 | fit progress: (45, 0, {}, 15.461113601922989)
# INFO flwr 2024-08-21 11:13:33,899 | server.py:171 | evaluate_round 45: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:33,901 | server.py:222 | fit_round 46: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:34,182 | server.py:236 | fit_round 46 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:34,208 | server.py:125 | fit progress: (46, 0, {}, 15.7713734023273)
# INFO flwr 2024-08-21 11:13:34,209 | server.py:171 | evaluate_round 46: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:34,211 | server.py:222 | fit_round 47: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:34,499 | server.py:236 | fit_round 47 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:34,524 | server.py:125 | fit progress: (47, 0, {}, 16.087190721184015)
# INFO flwr 2024-08-21 11:13:34,525 | server.py:171 | evaluate_round 47: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:34,527 | server.py:222 | fit_round 48: strategy sampled 2 clients (out of 2)
# (DefaultActor pid=2479244) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation. [repeated 32x across cluster]
# DEBUG flwr 2024-08-21 11:13:34,818 | server.py:236 | fit_round 48 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:34,843 | server.py:125 | fit progress: (48, 0, {}, 16.406892899423838)
# INFO flwr 2024-08-21 11:13:34,845 | server.py:171 | evaluate_round 48: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:34,846 | server.py:222 | fit_round 49: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:35,144 | server.py:236 | fit_round 49 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:35,169 | server.py:125 | fit progress: (49, 0, {}, 16.73281643167138)
# INFO flwr 2024-08-21 11:13:35,171 | server.py:171 | evaluate_round 49: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:35,172 | server.py:222 | fit_round 50: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:35,460 | server.py:236 | fit_round 50 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:35,484 | server.py:125 | fit progress: (50, 0, {}, 17.04792397096753)
# INFO flwr 2024-08-21 11:13:35,486 | server.py:171 | evaluate_round 50: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13
strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:43,181 | server.py:236 | fit_round 75 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:43,207 | server.py:125 | fit progress: (75, 0, {}, 24.770633295178413)
# INFO flwr 2024-08-21 11:13:43,208 | server.py:171 | evaluate_round 75: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:43,209 | server.py:222 | fit_round 76: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:43,487 | server.py:236 | fit_round 76 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:43,515 | server.py:125 | fit progress: (76, 0, {}, 25.078319814056158)
# INFO flwr 2024-08-21 11:13:43,516 | server.py:171 | evaluate_round 76: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:43,518 | server.py:222 | fit_round 77: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:43,797 | server.py:236 | fit_round 77 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:43,823 | server.py:125 | fit progress: (77, 0, {}, 25.386486127972603)
# INFO flwr 2024-08-21 11:13:43,825 | server.py:171 | evaluate_round 77: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:43,826 | server.py:222 | fit_round 78: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:44,105 | server.py:236 | fit_round 78 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:44,129 | server.py:125 | fit progress: (78, 0, {}, 25.692268442362547)
# INFO flwr 2024-08-21 11:13:44,130 | server.py:171 | evaluate_round 78: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:44,132 | server.py:222 | fit_round 79: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:44,407 | server.py:236 | fit_round 79 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:44,432 | server.py:125 | fit progress: (79, 0, {}, 25.995386708527803)
# INFO flwr 2024-08-21 11:13:44,433 | server.py:171 | evaluate_round 79: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:44,435 | server.py:222 | fit_round 80: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:44,707 | server.py:236 | fit_round 80 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:44,734 | server.py:125 | fit progress: (80, 0, {}, 26.297400757670403)
# INFO flwr 2024-08-21 11:13:44,735 | server.py:171 | evaluate_round 80: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:44,737 | server.py:222 | fit_round 81: strategy sampled 2 clients (out of 2)
# (DefaultActor pid=2479244) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation. [repeated 33x across cluster]
# DEBUG flwr 2024-08-21 11:13:44,997 | server.py:236 | fit_round 81 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:45,022 | server.py:125 | fit progress: (81, 0, {}, 26.585743755102158)
# INFO flwr 2024-08-21 11:13:45,025 | server.py:171 | evaluate_round 81: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:45,027 | server.py:222 | fit_round 82: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:45,311 | server.py:236 | fit_round 82 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:45,340 | server.py:125 | fit progress: (82, 0, {}, 26.903121277689934)
# INFO flwr 2024-08-21 11:13:45,341 | server.py:171 | evaluate_round 82: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:45,343 | server.py:222 | fit_round 83: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:45,609 | server.py:236 | fit_round 83 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:45,636 | server.py:125 | fit progress: (83, 0, {}, 27.2000172175467)
# INFO flwr 2024-08-21 11:13:45,638 | server.py:171 | evaluate_round 83: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:45,640 | server.py:222 | fit_round 84: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:45,932 | server.py:236 | fit_round 84 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:45,951 | server.py:125 | fit progress: (84, 0, {}, 27.515100859105587)
# INFO flwr 2024-08-21 11:13:45,953 | server.py:171 | evaluate_round 84: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:45,954 | server.py:222 | fit_round 85: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:46,226 | server.py:236 | fit_round 85 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:46,253 | server.py:125 | fit progress: (85, 0, {}, 27.816406708210707)
# INFO flwr 2024-08-21 11:13:46,254 | server.py:171 | evaluate_round 85: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:46,255 | server.py:222 | fit_round 86: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:46,516 | server.py:236 | fit_round 86 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:46,541 | server.py:125 | fit progress: (86, 0, {}, 28.1041057407856)
# INFO flwr 2024-08-21 11:13:46,542 | server.py:171 | evaluate_round 86: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:46,543 | server.py:222 | fit_round 87: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:46,813 | server.py:236 | fit_round 87 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13
received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:50,365 | server.py:125 | fit progress: (99, 0, {}, 31.928821321576834)
# INFO flwr 2024-08-21 11:13:50,367 | server.py:171 | evaluate_round 99: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:50,368 | server.py:222 | fit_round 100: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:50,675 | server.py:236 | fit_round 100 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:50,702 | server.py:125 | fit progress: (100, 0, {}, 32.26522896066308)
# INFO flwr 2024-08-21 11:13:50,703 | server.py:171 | evaluate_round 100: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:50,705 | server.py:222 | fit_round 101: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:51,059 | server.py:236 | fit_round 101 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:51,085 | server.py:125 | fit progress: (101, 0, {}, 32.648817867040634)
# INFO flwr 2024-08-21 11:13:51,087 | server.py:171 | evaluate_round 101: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:51,088 | server.py:222 | fit_round 102: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:51,421 | server.py:236 | fit_round 102 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:51,447 | server.py:125 | fit progress: (102, 0, {}, 33.010689198970795)
# INFO flwr 2024-08-21 11:13:51,449 | server.py:171 | evaluate_round 102: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:51,450 | server.py:222 | fit_round 103: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:51,728 | server.py:236 | fit_round 103 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:51,755 | server.py:125 | fit progress: (103, 0, {}, 33.31863225251436)
# INFO flwr 2024-08-21 11:13:51,757 | server.py:171 | evaluate_round 103: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:51,758 | server.py:222 | fit_round 104: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:52,020 | server.py:236 | fit_round 104 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:52,046 | server.py:125 | fit progress: (104, 0, {}, 33.60965196415782)
# INFO flwr 2024-08-21 11:13:52,048 | server.py:171 | evaluate_round 104: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:52,049 | server.py:222 | fit_round 105: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:52,312 | server.py:236 | fit_round 105 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:52,338 | server.py:125 | fit progress: (105, 0, {}, 33.901297975331545)
# INFO flwr 2024-08-21 11:13:52,339 | server.py:171 | evaluate_round 105: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:52,341 | server.py:222 | fit_round 106: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:52,654 | server.py:236 | fit_round 106 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:52,684 | server.py:125 | fit progress: (106, 0, {}, 34.24759491160512)
# INFO flwr 2024-08-21 11:13:52,686 | server.py:171 | evaluate_round 106: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:52,688 | server.py:222 | fit_round 107: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:52,973 | server.py:236 | fit_round 107 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:53,001 | server.py:125 | fit progress: (107, 0, {}, 34.564407497644424)
# INFO flwr 2024-08-21 11:13:53,002 | server.py:171 | evaluate_round 107: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:53,004 | server.py:222 | fit_round 108: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:53,282 | server.py:236 | fit_round 108 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:53,308 | server.py:125 | fit progress: (108, 0, {}, 34.87140038236976)
# INFO flwr 2024-08-21 11:13:53,309 | server.py:171 | evaluate_round 108: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:13:53,311 | server.py:222 | fit_round 109: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:13:53,600 | server.py:236 | fit_round 109 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:13:53,627 | server.py:125 | fit progress: (109, 0, {}, 35.19080726057291)
# ...
# (DefaultActor pid=2479243) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation. [repeated 28x across cluster]
# DEBUG flwr 2024-08-21 11:20:49,608 | server.py:236 | fit_round 1457 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:49,632 | server.py:125 | fit progress: (1457, 0, {}, 451.19598004966974)
# INFO flwr 2024-08-21 11:20:49,634 | server.py:171 | evaluate_round 1457: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:49,635 | server.py:222 | fit_round 1458: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:49,974 | server.py:236 | fit_round 1458 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:49,998 | server.py:125 | fit progress: (1458, 0, {}, 451.5619607530534)
# INFO flwr 2024-08-21 11:20:50,000 | server.py:171 | evaluate_round 1458: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:50,002 | server.py:222 | fit_round 1459: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:50,316 | server.py:236 | fit_round 1459 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:50,342 | server.py:125 | fit progress: (1459, 0, {}, 451.9053325355053)
# INFO flwr 2024-08-21 11:20:50,343 | server.py:171 | evaluate_round 1459: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:50,344 | server.py:222 | fit_round 1460: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:50,678 | server.py:236 | fit_round 1460 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:50,701 | server.py:125 | fit progress: (1460, 0, {}, 452.2648787088692)
# INFO flwr 2024-08-21 11:20:50,703 | server.py:171 | evaluate_round 1460: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:50,704 | server.py:222 | fit_round 1461: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:51,026 | server.py:236 | fit_round 1461 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:51,051 | server.py:125 | fit progress: (1461, 0, {}, 452.61456678807735)
# INFO flwr 2024-08-21 11:20:51,052 | server.py:171 | evaluate_round 1461: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:51,054 | server.py:222 | fit_round 1462: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:51,380 | server.py:236 | fit_round 1462 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:51,406 | server.py:125 | fit progress: (1462, 0, {}, 452.9691757597029)
# INFO flwr 2024-08-21 11:20:51,407 | server.py:171 | evaluate_round 1462: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:51,409 | server.py:222 | fit_round 1463: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:51,727 | server.py:236 | fit_round 1463 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:51,751 | server.py:125 | fit progress: (1463, 0, {}, 453.3144730515778)
# INFO flwr 2024-08-21 11:20:51,752 | server.py:171 | evaluate_round 1463: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:51,753 | server.py:222 | fit_round 1464: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:52,072 | server.py:236 | fit_round 1464 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:52,099 | server.py:125 | fit progress: (1464, 0, {}, 453.6622691117227)
# INFO flwr 2024-08-21 11:20:52,100 | server.py:171 | evaluate_round 1464: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:52,102 | server.py:222 | fit_round 1465: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:52,408 | server.py:236 | fit_round 1465 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:52,434 | server.py:125 | fit progress: (1465, 0, {}, 453.9972837716341)
# INFO flwr 2024-08-21 11:20:52,435 | server.py:171 | evaluate_round 1465: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:52,437 | server.py:222 | fit_round 1466: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:52,751 | server.py:236 | fit_round 1466 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:52,774 | server.py:125 | fit progress: (1466, 0, {}, 454.3379213064909)
# INFO flwr 2024-08-21 11:20:52,776 | server.py:171 | evaluate_round 1466: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:52,777 | server.py:222 | fit_round 1467: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:53,100 | server.py:236 | fit_round 1467 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:53,124 | server.py:125 | fit progress: (1467, 0, {}, 454.6876614652574)
# INFO flwr 2024-08-21 11:20:53,125 | server.py:171 | evaluate_round 1467: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:53,126 | server.py:222 | fit_round 1468: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:53,438 | server.py:236 | fit_round 1468 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:53,462 | server.py:125 | fit progress: (1468, 0, {}, 455.0256298854947)
# INFO flwr 2024-08-21 11:20:53,463 | server.py:171 | evaluate_round 1468: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:53,466 | server.py:222 | fit_round 1469: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:53,779 | server.py:236 | fit_round 1469 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:53,805 | server.py:125 | fit progress: (1469, 0, {}, 455.368305593729)
# INFO flwr 2024-08-21 11:20:53,806 | server.py:171 | evaluate_round 1469: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:53,808 | server.py:222 | fit_round 1470: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:54,120 | server.py:236 | fit_round 1470 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:54,147 | server.py:125 | fit progress: (1470, 0, {}, 455.7106657549739)
# INFO flwr 2024-08-21 11:20:54,149 | server.py:171 | evaluate_round 1470: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:54,150 | server.py:222 | fit_round 1471: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:54,461 | server.py:236 | fit_round 1471 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20
no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:58,051 | server.py:222 | fit_round 1483: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:58,357 | server.py:236 | fit_round 1483 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:58,376 | server.py:125 | fit progress: (1483, 0, {}, 459.93984416127205)
# INFO flwr 2024-08-21 11:20:58,377 | server.py:171 | evaluate_round 1483: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:58,379 | server.py:222 | fit_round 1484: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:58,678 | server.py:236 | fit_round 1484 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:58,703 | server.py:125 | fit progress: (1484, 0, {}, 460.26695481687784)
# INFO flwr 2024-08-21 11:20:58,705 | server.py:171 | evaluate_round 1484: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:58,706 | server.py:222 | fit_round 1485: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:59,010 | server.py:236 | fit_round 1485 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:59,035 | server.py:125 | fit progress: (1485, 0, {}, 460.59856152907014)
# INFO flwr 2024-08-21 11:20:59,036 | server.py:171 | evaluate_round 1485: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:59,038 | server.py:222 | fit_round 1486: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:59,329 | server.py:236 | fit_round 1486 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:59,346 | server.py:125 | fit progress: (1486, 0, {}, 460.9101068601012)
# INFO flwr 2024-08-21 11:20:59,348 | server.py:171 | evaluate_round 1486: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:59,349 | server.py:222 | fit_round 1487: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:20:59,657 | server.py:236 | fit_round 1487 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:20:59,682 | server.py:125 | fit progress: (1487, 0, {}, 461.2459758296609)
# INFO flwr 2024-08-21 11:20:59,684 | server.py:171 | evaluate_round 1487: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:20:59,685 | server.py:222 | fit_round 1488: strategy sampled 2 clients (out of 2)
# (DefaultActor pid=2479244) /tmp/ipykernel_2478336/362643865.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation. [repeated 32x across cluster]
# DEBUG flwr 2024-08-21 11:20:59,991 | server.py:236 | fit_round 1488 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:21:00,014 | server.py:125 | fit progress: (1488, 0, {}, 461.57757487148046)
# INFO flwr 2024-08-21 11:21:00,015 | server.py:171 | evaluate_round 1488: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:21:00,017 | server.py:222 | fit_round 1489: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:21:00,320 | server.py:236 | fit_round 1489 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:21:00,344 | server.py:125 | fit progress: (1489, 0, {}, 461.9072099849582)
# INFO flwr 2024-08-21 11:21:00,345 | server.py:171 | evaluate_round 1489: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:21:00,346 | server.py:222 | fit_round 1490: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:21:00,647 | server.py:236 | fit_round 1490 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:21:00,672 | server.py:125 | fit progress: (1490, 0, {}, 462.23556005582213)
# INFO flwr 2024-08-21 11:21:00,673 | server.py:171 | evaluate_round 1490: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:21:00,674 | server.py:222 | fit_round 1491: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:21:00,964 | server.py:236 | fit_round 1491 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:21:00,988 | server.py:125 | fit progress: (1491, 0, {}, 462.55173686891794)
# INFO flwr 2024-08-21 11:21:00,989 | server.py:171 | evaluate_round 1491: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:21:00,991 | server.py:222 | fit_round 1492: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2024-08-21 11:21:01,291 | server.py:236 | fit_round 1492 received 2 results and 0 failures
# INFO flwr 2024-08-21 11:21:01,316 | server.py:125 | fit progress: (1492, 0, {}, 462.8793388046324)
# INFO flwr 2024-08-21 11:21:01,317 | server.py:171 | evaluate_round 1492: no clients selected, cancel
# DEBUG flwr 2024-08-21 11:21:01,318 | server.py:222 | fit_round 1493: strategy sampled 2 clients (out of 2)

# %%
from submit_email import send_email
send_email("FederatedLossyCounting " + str(NUM_CLIENTS) + " nodes")
